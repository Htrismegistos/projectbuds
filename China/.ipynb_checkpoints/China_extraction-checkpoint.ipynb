# %% [markdown]
# dates has different table layouts: see: # RESULT table layout differencies
# checking 5 table layout for tables data boundaries. different by tables: see:table structure
# checking 5 table layout, tables has different no of rows at some dates: see:lengthoutlayer
# there are 3 variations. data bounderies compared to normal table boundaries

# %%
import json
from bs4 import BeautifulSoup as beauty
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
tables = json.load(open('china_tables.json', 'r'))
len(tables)
# Out:
# 59

# %%
dates = sorted(list(tables.keys()))

# %%
#check data homogenity by no of tables per page
l = []
for i in dates:
    l.append(len(beauty(tables[i], 'lxml').find_all('tbody')))
set(l)
# Out:
# {2, 4, 5, 6}

# %%
layout = {2: [], 4:[], 5:[],6:[]}
for i, d in zip(l,dates):
    if i == 2:
        layout[2].append(d)
    elif i == 4:
        layout[4].append(d)
    elif i == 5:
        layout[5].append(d)
    else:
        layout[6].append(d)

# %%
# RESULT table layout differencies
for i in layout.keys():
    print('{} tables: {}'.format(i,len(layout[i])))
# Out:
# 2 tables: 2
# 4 tables: 12
# 5 tables: 38
# 6 tables: 7

# %%
#analysing table layout at all layout sttings. see layout.keys

for i in layout[5][:]:
#for i in lengthoutlayer[:10]:
    print(i)
    
    for n in range(2,3):
        
        #code to identify adat allocations
        print(beauty(tables[i], 'lxml').find_all('tbody')[n].find_all('tr')[1].text)
        print(beauty(tables[i], 'lxml').find_all('tbody')[n].find_all('tr')[0].text)
        print(beauty(tables[i], 'lxml').find_all('tbody')[n].find_all('tr')[2].text)
        print(beauty(tables[i], 'lxml').find_all('tbody')[n].find_all('tr')[3].text)
        print(beauty(tables[i], 'lxml').find_all('tbody')[n].find_all('tr')[4].text)
        print('\tbottom')
        print(beauty(tables[i], 'lxml').find_all('tbody')[n].find_all('tr')[-2].text)
# Out:
# 201407
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    100.0    104.2    114.3    Dali   99.8    99.6    103.7
# 201408
#   Table III
#   Sales Price Indices of Residential Buildings in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    99.6    103.3    113.9    Dali   99.4    99.2    103.1
# 201409
#   Table III
#     Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    99.9    102.8    113.8    Dali   99.7    98.7    102.9
# 201410
#   Table III
#     Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    99.0    101.4    112.7    Dali   99.3    97.7    102.1
# 201411
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    98.9    99.8    111.4    Dali   99.5    96.6    101.6
# 201412
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    99.8    99.4    111.1    Dali   99.6    95.8    101.2
# 201501
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    100.0    98.9    111.1    Dali   98.4    94.2    99.6
# 201502
#   Table III
#     Sales Price Indices of Residential Buildings in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    99.8   98.4   110.9   Dali   99.6   94.1   99.2
# 201503
#   Table III
#   Sales Price Indices of Residential Buildings in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    99.6    97.7    110.5    Dali   99.5    94.1    98.7
# 201504
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    99.9    97.2    110.4    Dali   99.4    93.6    98.1
# 201506
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    100.8    97.6    111.6    Dali   99.7    93.3    96.9
# 201510
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi   100.9    98.4    112.5    Dali   99.8    93.3    96.7
# 201511
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    100.3    102.3    113.9    Dali   100.0    94.4    95.9
# 201512
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    100.3    102.8    114.2    Dali   99.8    94.6    95.7
# 201601
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    100.1    102.9    114.3    Dali   100.0    96.1    95.7
# 201602
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    99.5    102.5    101.2    Dali   100.1    96.4    98.8
# 201603
#   Table III
#   Sales Price Indices of Residential Buildings in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    98.9    101.8    100.1    Dali   100.4    97.3    99.2
# 201604
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    99.3    101.2    99.5    Dali   100.2    98.2    99.4
# 201605
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    99.8    100.7    99.3    Dali   100.1    99.3    99.6
# 201606
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    99.9    99.9    99.2    Dali   100.3    99.8    99.8
# 201607
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    99.8    98.9    98.9    Dali   99.8    99.8    99.6
# 201608
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    99.8    98.1    98.7    Dali   100.2    100.1    99.8
# 201609
#   Table III
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    100.0    97.9    98.7    Dali   99.6    99.8    99.3
# 201610
#   Table IV
#     Sales Price Indices of Second-Hand Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    99.9    97.7    98.6    Dali   99.9    100.3    99.2
# 201701
#   Table IV
#   Sales Price Indices of Second-Hand Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    99.9    96.3    97.9    Dali   99.6    100.3    99.0
# 201703
#   Table IV
#     Sales Price Indices of Second-Hand Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    100.2    98.5    98.7    Dali   99.9    99.5    98.7
# 201707
#   Table IV
#   Sales Price Indices of Second-Hand Residential Buildings in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    100.6    101.4    100.3    Dali   100.4    99.8    99.4
# 201708
#   Table IV
#   Sales Price Indices of Second-Hand Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    101.3    103.0    101.7    Dali   100.0    99.6    99.4
# 201709
#   Table IV
#   Sales Price Indices of Second-Hand Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#   previous month=100   the same month last year=100   Year 2015=100   previous month=100   the same month last year=100   Year 2015=100
# 	bottom
#   Urumqi    101.0    104.0    102.7    Dali   100.2    100.3    99.6
# 201710
#   Table IV
#   Sales Price Indices of Second-Hand Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    100.8    105.0    103.5    Dali   100.4    100.8    100.0
# 201711
#   Table IV
#   Sales Price Indices of Second-Hand Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    101.0    106.3    104.6    Dali   100.3    101.2    100.3
# 201712
#   Table IV
#   Sales Price Indices of Second-Hand Residential Buildings in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    101.8    108.6    106.5    Dali   100.5    101.4    100.8
# 201801
#   Table IV
#   Sales Price Indices of Second-Hand Residential Buildings  in 70 Large and Medium-Sized Cities
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
# 	bottom
#   Urumqi    100.8    109.6    107.3    Dali   101.0    102.8    101.8
# 201804
#   Table III
#   Price Indices of Newly Constructed Residential Buildings  by Floor Space in 70 Large and Medium-Sized Cities
#   Cities   90m2 and Below   90-144m2   Above 144m2
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#   Last Month=100   the Same Month Last Year=100   Year 2015=100   Last Month=100   the Same Month Last Year=100   Year 2015=100   Last Month=100   the Same Month Last Year=100   Year 2015=100
# 	bottom
#   Dali   100.9    110.8    113.9    101.1    107.6    111.0    100.7    107.3    109.1
# 201805
#   Table III
#   Price Indices of Newly Constructed Residential Buildings  by Floor Space in 70 Large and Medium-Sized Cities
#   Cities   90m2 and Below   90-144m2   Above 144m2
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#   Last Month=100   the Same Month Last Year=100   Year 2015=100   Last Month=100   the Same Month Last Year=100   Year 2015=100   Last Month=100   the Same Month Last Year=100   Year 2015=100
# 	bottom
#   Dali   101.3    111.8    115.4    101.3    108.3    112.5    101.1    107.7    110.3
# 201806
#   Table III
#   Price Indices of Newly Constructed Residential Buildings  by Floor Space in 70 Large and Medium-Sized Cities
#   Cities   90m2 and Below   90-144m2   Above 144m2
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#   Last Month=100   the Same Month Last Year=100   Year 2015=100   Last Month=100   the Same Month Last Year=100   Year 2015=100   Last Month=100   the Same Month Last Year=100   Year 2015=100
# 	bottom
#   Dali   100.5    111.2    116.0    100.5    108.4    113.1    101.2    109.2    111.7
# 201807
#   Table III
#   Price Indices of Newly Constructed Residential Buildings  by Floor Space in 70 Large and Medium-Sized Cities
#   Cities   90m2 and Below   90-144m2   Above 144m2
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#   Last Month=100   the Same Month Last Year=100   Year 2015=100   Last Month=100   the Same Month Last Year=100   Year 2015=100   Last Month=100   the Same Month Last Year=100   Year 2015=100
# 	bottom
#   Dali   100.7    111.8    116.9    101.7    109.6    115.0    101.0    109.4    112.8
# 201808
#   Table III
#   Price Indices of Newly Constructed Residential Buildings  by Floor Space in 70 Large and Medium-Sized Cities
#   Cities   90m2 and Below   90-144m2   Above 144m2
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#   Last Month=100   the Same Month Last Year=100   Year 2015=100   Last Month=100   the Same Month Last Year=100   Year 2015=100   Last Month=100   the Same Month Last Year=100   Year 2015=100
# 	bottom
#   Dali   101.5    112.8    118.6    102.3    112.2    117.7    100.9    110.0    113.8

# %%
#to identify row homogenity across layout types
lengthoutlayer = []
lengthnormal = []
for i in layout[5][:]:
    l = []  # tablelength temp
    for n in range(5):
        
        l.append(len(beauty(tables[i], 'lxml').find_all('tbody')[n].find_all('tr')))
    if l != [42,41,41,76,76]:
        lengthoutlayer.append(i)
    else: lengthnormal.append(i)
        
print('{} dates has different row numbers'.format(len(lengthoutlayer)))
# Out:
# 15 dates has different row numbers

# %%
#examining outlayers
for m,i in enumerate(lengthoutlayer):
    l = []  # tablelength temp
    for n in range(5):
        
        l.append(len(beauty(tables[i], 'lxml').find_all('tbody')[n].find_all('tr')))
    print(m,i, l)
# Out:
# 0 201610 [66, 41, 41, 76, 76]
# 1 201701 [66, 41, 41, 76, 76]
# 2 201703 [66, 41, 41, 76, 76]
# 3 201707 [66, 41, 41, 76, 76]
# 4 201708 [66, 41, 41, 76, 76]
# 5 201709 [66, 42, 42, 77, 77]
# 6 201710 [66, 41, 41, 76, 76]
# 7 201711 [66, 41, 41, 76, 76]
# 8 201712 [66, 41, 41, 76, 75]
# 9 201801 [65, 41, 41, 76, 76]
# 10 201804 [42, 41, 77, 77, 22]
# 11 201805 [42, 41, 77, 77, 22]
# 12 201806 [42, 41, 77, 77, 22]
# 13 201807 [42, 41, 77, 77, 22]
# 14 201808 [42, 41, 77, 77, 22]

# %% [markdown]
# #RESULT table structure:
#     start tr[5]
#     lengthnormal [42,41,41,76,76]
#         -table 1: tr[-3] Newly Constructed Residential Buildings
#         table 2: tr[-2] Newly Constructed Commercial Residential Buildings
#         -table 3: tr[-2] Second-Hand Residential Buildings - All
#         table 4: tr[-2] Newly Constructed Residential Buildings by Floor Space
#         table 5: tr[-2] Second-Hand Residential Buildings by Floor Space
#     lengthoutlayer[10:]  [42, 41, 77, 77, 22]
#         -table 1: tr[6;-2] Newly Constructed Residential Buildings
#         -table 2: tr[5;-2] Second-Hand Residential Buildings
#         table 3: tr[6,-2] Newly Constructed Residential Buildings by Floor Space
#         table 4: tr[6,-2] Second-Hand Residential Buildings by Floor Space
#         table 5: tr[6;-2] Newly Constructed Commercial Residential in 15 Hot Cities
#     lengthoutlayer[:9] [66, 41, 41, 76, 76]
#         table 1:  tr[6;-4] Newly Constructed Commercial Residential in 15 Hot Cities
#         -table 2: tr[5;-2] Newly Constructed Commercial Residential Buildings
#         -table 3: tr[5,-2] Second-Hand Residential Buildings - All
#         table 4: tr[5,-2] Newly Constructed Residential Buildings by Floor Space
#         table 5: tr[5,-2] Second-Hand Residential Buildings by Floor Space
#     lengthoutlayer[9] [65, 41, 41, 76, 76]
#         table 1:  tr[6;-3] Newly Constructed Commercial Residential in 15 Hot Cities
#         -table 2: tr[5;-2] Newly Constructed Commercial Residential Buildings
#         -table 3: tr[5,-2] Second-Hand Residential Buildings - All
#         table 4: tr[5,-2] Newly Constructed Residential Buildings by Floor Space
#         table 5: tr[5,-2] Second-Hand Residential Buildings by Floor Space
#     lengthoutlayer[5] [66, 42, 42, 77, 77]
#         table 1:  tr[6;-3] Newly Constructed Commercial Residential in 15 Hot Cities
#         -table 2: tr[6;-2] Newly Constructed Commercial Residential Buildings
#         -table 3: tr[6,-2] Second-Hand Residential Buildings - All
#         table 4: tr[6,-2] Newly Constructed Residential Buildings by Floor Space
#         table 5: tr[6,-2] Second-Hand Residential Buildings by Floor Space
#     lengthoutlayer[8]
#         table 1:  tr[6;-4] Newly Constructed Commercial Residential in 15 Hot Cities
#         -table 2: tr[5;-2] Newly Constructed Commercial Residential Buildings
#         -table 3: tr[5,-2] Second-Hand Residential Buildings - All
#         table 4: tr[5,-2] Newly Constructed Residential Buildings by Floor Space
#         table 5: tr[4,-2] Second-Hand Residential Buildings by Floor Space

# %% [markdown]
# #### Newly Constructed Commercial Residential Buildings

# %%
#table structure
print(beauty(tables[lengthnormal[0]],'lxml').find_all('tbody')[0].find_all('tr')[3].text)
print(beauty(tables[lengthnormal[0]],'lxml').find_all('tbody')[0].find_all('tr')[5].text)
# Out:
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#   Beijing    100.1    106.4    122.6    Tangshan    100.0    100.7    103.2

# %%
newCRes = pd.DataFrame()
for i in lengthnormal:
    l = len(beauty(tables[i],'lxml').find_all('tbody')[0].find_all('tr'))
    dick = {}
    for n in range(5,l-2):
        c = beauty(tables[i],'lxml').find_all('tbody')[0].find_all('tr')[n].find_all('td')[0].text.strip()
        v = beauty(tables[i],'lxml').find_all('tbody')[0].find_all('tr')[n].find_all('td')[1].text.strip()
        dick[c] = v
    for n in range(5,l-2):
        c = beauty(tables[i],'lxml').find_all('tbody')[0].find_all('tr')[n].find_all('td')[4].text.strip()
        v = beauty(tables[i],'lxml').find_all('tbody')[0].find_all('tr')[n].find_all('td')[5].text.strip()
        dick[c] = v
    df = pd.DataFrame(dick.values(), columns = [i], index = dick.keys())
    newCRes = pd.concat([newCRes,df], sort = True, axis =1)

# %%
print(beauty(tables[lengthoutlayer[10]],'lxml').find_all('tbody')[0].find_all('tr')[0].text)
for i in lengthoutlayer[10:]:
    print(i)
    l = len(beauty(tables[i],'lxml').find_all('tbody')[0].find_all('tr'))
    dick = {}
    for n in range(6,l-1):
        c = beauty(tables[i],'lxml').find_all('tbody')[0].find_all('tr')[n].find_all('td')[0].text.strip()
        v = beauty(tables[i],'lxml').find_all('tbody')[0].find_all('tr')[n].find_all('td')[1].text.strip()
        dick[c] = v
    for n in range(6,l-1):
        c = beauty(tables[i],'lxml').find_all('tbody')[0].find_all('tr')[n].find_all('td')[4].text.strip()
        v = beauty(tables[i],'lxml').find_all('tbody')[0].find_all('tr')[n].find_all('td')[5].text.strip()
        dick[c] = v
    df = pd.DataFrame(dick.values(), columns = [i], index = dick.keys())
    newCRes = pd.concat([newCRes,df], sort= True, axis =1)
# Out:
#   Sales Price Indices of Newly Constructed Commercial Residential Buildings in 70 Large and Medium-Sized Cities
# 201804
# 201805
# 201806
# 201807
# 201808

# %%
print(beauty(tables[lengthoutlayer[0]],'lxml').find_all('tbody')[1].find_all('tr')[0].text)
for i in lengthoutlayer[:10]:
    print(i)
    l = len(beauty(tables[i],'lxml').find_all('tbody')[1].find_all('tr'))
    dick = {}
    for n in range(5,l-1):
        c = beauty(tables[i],'lxml').find_all('tbody')[1].find_all('tr')[n].find_all('td')[0].text.strip().replace('*','')
        v = beauty(tables[i],'lxml').find_all('tbody')[1].find_all('tr')[n].find_all('td')[1].text.strip()
        dick[c] = v
    for n in range(5,l-1):
        c = beauty(tables[i],'lxml').find_all('tbody')[1].find_all('tr')[n].find_all('td')[4].text.strip()
        v = beauty(tables[i],'lxml').find_all('tbody')[1].find_all('tr')[n].find_all('td')[5].text.strip()
        dick[c] = v
    df = pd.DataFrame(dick.values(), columns = [i], index = dick.keys())
    newCRes = pd.concat([newCRes,df], sort= True, axis =1)
# Out:
#   Sales Price Indices of Commercial Residential Buildings  in 70 Large and Medium-Sized Cities
# 201610
# 201701
# 201703
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801

# %%
backup=newCRes.copy()

# %%
newCRes
# Out:
#              201407 201408 201409 201410 201411 201412 201501 201502 201503  \
#                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Anqing         99.7   99.2   98.9   98.7   99.3   99.1   99.5   99.8   99.6
# Baotou         99.5   98.9   98.5   99.3   99.4   99.3   99.5   98.9   99.1
# Beihai         99.5   99.5   98.6   98.9   99.2   99.0   99.9   99.2   99.7
# Beijing       100.1   99.0   99.1   99.3   98.9   99.8   99.8   99.9   99.8
# Bengbu         99.5   99.4   99.1   98.1   98.8   99.3   99.6   99.5   99.3
# Changchun      99.4   99.3   99.2   98.7   99.4   99.4   99.5   99.8   99.7
# Changde        99.5   99.0   99.0   99.3   99.4   99.7   99.8   99.2   99.3
# Changsha       99.1   98.6   98.4   99.0   98.7   99.1   99.3   99.7   99.6
# Chengdu        99.4   98.9   98.8   98.9   98.8   99.4   99.8   99.7   99.6
# Chongqing      99.2   99.1   98.7   98.2   99.3   99.5   99.7   99.6   99.4
# Dali          100.0  100.1   98.9   99.5   99.1   99.4   99.4   99.6   99.5
# Dalian        100.0   98.7   98.4   99.0   98.7   98.6   99.0   99.4   99.6
# Dandong        99.4   99.5   99.2   98.3   98.7   98.7   99.4   98.4   99.3
# Fuzhou         99.3   98.5   98.8   98.2   99.0   99.6   99.8   99.5   99.3
# Ganzhou        99.2   98.9   98.8   98.4   99.2   99.4  100.0  100.2  100.1
# Guangzhou      99.4   98.7   98.7   98.6   98.8   99.6   99.8  100.0   99.8
# Beihai        100.7  100.3   99.7
# Beijing        99.8  100.0  100.0
# Bengbu         99.4  100.0   99.7
# Changchun     100.5  100.7  101.2
# Changde       100.5  100.1  100.6
# Changsha      100.3  100.0  100.2
# Chengdu       100.7  100.1  100.5
# Chongqing     100.2  100.6  100.4
# Dali          100.3  100.6  101.5
# Dalian        100.7  101.0  100.8
# Dandong       100.0  101.0  101.2
# Fuzhou        100.0  100.2   99.8
# Ganzhou        99.7  100.0   99.7
# Guangzhou      99.8   99.9   99.7
# Guilin        100.4  101.3  100.3
# Guiyang       100.4  100.9  101.2
# Haikou        100.0   99.8  102.2
# Hangzhou      100.0   99.9  100.0
# Harbin        101.7  100.4  101.0
# Hefei         100.0  100.1  100.0
# Hohhot        100.9  101.1  100.8
# Huizhou       100.2  100.4  100.2
# Jilin         100.5  100.4  100.3
# Jinan          99.8   99.9  100.3
# Jinhua        100.5  100.4  100.5
# Jining        100.4  100.2  100.4
# Jinzhou       100.1  100.3  100.1
# ...             ...    ...    ...
# Pingdingshan  100.5  100.6  100.5
# Qingdao       100.3  100.5  100.2
# Qinhuangdao   100.5  100.9  100.1
# Quanzhou      100.4   99.6  100.6
# Sanya         100.2  100.8  100.5
# Shanghai      100.3  100.0  100.3
# Shaoguan      100.1  100.0  100.4
# Shenyang      100.6  100.8  100.4
# Shenzhen       99.9   99.8   99.8
# Shijiazhuang  100.2  100.2  100.0
# Taiyuan       100.7  100.4  100.6
# Tangshan       99.9  100.6  100.6
# Tianjin       100.1   99.7  100.2
# Urumqi        100.5  101.9  101.0
# Wenzhou       100.3  100.4  100.6
# Wuhan          99.9  100.0  100.3
# Wuxi           99.7   99.8  100.2
# Xiamen         99.8  100.2   99.8
# Xiangfan       99.8  100.3  100.0
# Xining        100.0  101.3  101.1
# Xi’an         100.7  100.5  100.6
# Xuzhou        100.5  100.6  100.2
# Yangzhou      100.5   99.7  100.3
# Yantai        100.6  100.7  100.4
# Yichang        99.8  100.5  100.4
# Yinchuan      100.1  101.0  100.5
# Yueyang       100.8  100.4  100.7
# Zhanjiang     100.2  101.5  100.3
# Zhengzhou      99.9  100.0  100.3
# Zunyi         100.7  100.5  101.0
#
# [71 rows x 38 columns]

# %%
newCRes.drop(index='', axis=0, inplace=True)

# %%
newCRes.to_csv('newRes38.csv')

# %%
plt.plot(newCRes.columns, newCRes.loc['Shenzhen'].astype(float), label = 'Shenzhen')
plt.plot(newCRes.columns, newCRes.loc['Beijing'].astype(float), label = 'Beijing')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# #### Second-Hand Residential Buildings

# %%
print(beauty(tables[lengthnormal[0]],'lxml').find_all('tbody')[2].find_all('tr')[2].text)
print(beauty(tables[lengthnormal[0]],'lxml').find_all('tbody')[2].find_all('tr')[4].text)
print(beauty(tables[lengthnormal[0]],'lxml').find_all('tbody')[2].find_all('tr')[5].text)
print(beauty(tables[lengthnormal[0]],'lxml').find_all('tbody')[2].find_all('tr')[-2].text)
print(beauty(tables[lengthoutlayer[0]],'lxml').find_all('tbody')[2].find_all('tr')[0].text)
print(beauty(tables[lengthoutlayer[0]],'lxml').find_all('tbody')[2].find_all('tr')[4].text)
print(beauty(tables[lengthoutlayer[0]],'lxml').find_all('tbody')[2].find_all('tr')[5].text)
print(beauty(tables[lengthoutlayer[0]],'lxml').find_all('tbody')[2].find_all('tr')[-2].text)
# Out:
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#
#   Beijing    98.7    104.7    117.6    Tangshan    99.7    100.3    104.0
#   Urumqi    100.0    104.2    114.3    Dali   99.8    99.6    103.7
#     Sales Price Indices of Second-Hand Residential Buildings  in 70 Large and Medium-Sized Cities
#
#   Beijing    105.7    140.5    148.2    Tangshan    100.0    100.0    99.8
#   Urumqi    99.9    97.7    98.6    Dali   99.9    100.3    99.2

# %%
secRes = pd.DataFrame()
#print(beauty(tables[lengthoutlayer[0]],'lxml').find_all('tbody')[2].find_all('tr')[0].text)

for i in lengthnormal+lengthoutlayer[:10]:
    print(i)
    l = len(beauty(tables[i],'lxml').find_all('tbody')[2].find_all('tr'))
    dick = {}
    for n in range(5,l-1):
        c = beauty(tables[i],'lxml').find_all('tbody')[2].find_all('tr')[n].find_all('td')[0].text.strip()
        v = beauty(tables[i],'lxml').find_all('tbody')[2].find_all('tr')[n].find_all('td')[1].text.strip()
        dick[c] = v
    for n in range(5,l-1):
        c = beauty(tables[i],'lxml').find_all('tbody')[2].find_all('tr')[n].find_all('td')[4].text.strip()
        v = beauty(tables[i],'lxml').find_all('tbody')[2].find_all('tr')[n].find_all('td')[5].text.strip()
        dick[c] = v
    df = pd.DataFrame(dick.values(), columns = [i], index = dick.keys())
    secRes = pd.concat([secRes,df], sort = True, axis =1)
# Out:
# 201407
# 201408
# 201409
# 201410
# 201411
# 201412
# 201501
# 201502
# 201503
# 201504
# 201506
# 201510
# 201511
# 201512
# 201601
# 201602
# 201603
# 201604
# 201605
# 201606
# 201607
# 201608
# 201609
# 201610
# 201701
# 201703
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801

# %%
for i in lengthoutlayer[10:]:
    print(i)
    l = len(beauty(tables[i],'lxml').find_all('tbody')[1].find_all('tr'))
    dick = {}
    for n in range(5,l-1):
        c = beauty(tables[i],'lxml').find_all('tbody')[1].find_all('tr')[n].find_all('td')[0].text.strip()
        v = beauty(tables[i],'lxml').find_all('tbody')[1].find_all('tr')[n].find_all('td')[1].text.strip()
        dick[c] = v
    for n in range(5,l-1):
        c = beauty(tables[i],'lxml').find_all('tbody')[1].find_all('tr')[n].find_all('td')[4].text.strip()
        v = beauty(tables[i],'lxml').find_all('tbody')[1].find_all('tr')[n].find_all('td')[5].text.strip()
        dick[c] = v
    df = pd.DataFrame(dick.values(), columns = [i], index = dick.keys())
    secRes = pd.concat([secRes,df], sort = True, axis =1)
# Out:
# 201804
# 201805
# 201806
# 201807
# 201808

# %%
secRes = secRes[sorted(secRes.columns)]

# %%
secRes.columns
# Out:
# Index(['201407', '201408', '201409', '201410', '201411', '201412', '201501',
#        '201502', '201503', '201504', '201506', '201510', '201511', '201512',
#        '201601', '201602', '201603', '201604', '201605', '201606', '201607',
#        '201608', '201609', '201610', '201701', '201703', '201707', '201708',
#        '201709', '201710', '201711', '201712', '201801', '201804', '201805',
#        '201806', '201807', '201808'],
#       dtype='object')

# %%
#secRes.loc[:,'201501']

# %%
secRes.to_csv('secRes38.csv')

# %%
fig = plt.figure(figsize= (10,5))
plt.plot(secRes.columns, secRes.loc['Beijing', :])
#plt.plot(secRes.columns, secRes.loc['Shenzhen', :])
plt.xticks(rotation=45);

# %% [markdown]
# #### Newly Constructed Residential Buildings by Floor Space

# %%
newRes90 = pd.DataFrame()
#print(beauty(tables[lengthoutlayer[0]],'lxml').find_all('tbody')[2].find_all('tr')[0].text)

for i in lengthnormal+lengthoutlayer[:10]:
    print(i)
    l = len(beauty(tables[i],'lxml').find_all('tbody')[3].find_all('tr'))
    dick = {}
    for n in range(5,l-1):
        c = beauty(tables[i],'lxml').find_all('tbody')[3].find_all('tr')[n].find_all('td')[0].text.strip()
        v = beauty(tables[i],'lxml').find_all('tbody')[3].find_all('tr')[n].find_all('td')[1].text.strip()
        dick[c] = v
    for n in range(5,l-1):
        c = beauty(tables[i],'lxml').find_all('tbody')[3].find_all('tr')[n].find_all('td')[4].text.strip()
        v = beauty(tables[i],'lxml').find_all('tbody')[3].find_all('tr')[n].find_all('td')[5].text.strip()
        dick[c] = v
    df = pd.DataFrame(dick.values(), columns = [i], index = dick.keys())
    newRes90 = pd.concat([newRes90,df], sort = True, axis =1)
# Out:
# 201407
# 201408
# 201409
# 201410
# 201411
# 201412
# 201501
# 201502
# 201503
# 201504
# 201506
# 201510
# 201511
# 201512
# 201601
# 201602
# 201603
# 201604
# 201605
# 201606
# 201607
# 201608
# 201609
# 201610
# 201701
# 201703
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801

# %%
for i in lengthoutlayer[10:]:
    print(i)
    l = len(beauty(tables[i],'lxml').find_all('tbody')[2].find_all('tr'))
    dick = {}
    for n in range(6,l-1):
        c = beauty(tables[i],'lxml').find_all('tbody')[2].find_all('tr')[n].find_all('td')[0].text.strip()
        v = beauty(tables[i],'lxml').find_all('tbody')[2].find_all('tr')[n].find_all('td')[1].text.strip()
        dick[c] = v
    df = pd.DataFrame(dick.values(), columns = [i], index = dick.keys())
    newRes90 = pd.concat([newRes90,df], sort = True, axis =1)
# Out:
# 201804
# 201805
# 201806
# 201807
# 201808

# %%
newRes90 = newRes90[sorted(newRes90.columns)]

# %%
newRes90.dropna(inplace=True)

# %%
#check value integrity
newRes90.loc[:,'201501']

# %%
newRes90.to_csv('newRes90.csv', index_label = None)

# %% [markdown]
# #### Second-Hand Residential Buildings by Floor Space

# %%
secRes90 = pd.DataFrame()

for i in lengthnormal+lengthoutlayer[:10]:
    print(i)
    l = len(beauty(tables[i],'lxml').find_all('tbody')[4].find_all('tr'))
    dick = {}
    for n in range(5,l-1):
        c = beauty(tables[i],'lxml').find_all('tbody')[4].find_all('tr')[n].find_all('td')[0].text.strip().replace('*','')
        v = beauty(tables[i],'lxml').find_all('tbody')[4].find_all('tr')[n].find_all('td')[1].text.strip()
        dick[c] = v
    df = pd.DataFrame(dick.values(), columns = [i], index = dick.keys())
    secRes90 = pd.concat([secRes90,df], sort = True, axis =1)
# Out:
# 201407
# 201408
# 201409
# 201410
# 201411
# 201412
# 201501
# 201502
# 201503
# 201504
# 201506
# 201510
# 201511
# 201512
# 201601
# 201602
# 201603
# 201604
# 201605
# 201606
# 201607
# 201608
# 201609
# 201610
# 201701
# 201703
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801

# %%
for i in lengthoutlayer[10:]:
    print(i)
    l = len(beauty(tables[i],'lxml').find_all('tbody')[3].find_all('tr'))
    dick = {}
    for n in range(6,l-1):
        c = beauty(tables[i],'lxml').find_all('tbody')[3].find_all('tr')[n].find_all('td')[0].text.strip().replace('*','')
        v = beauty(tables[i],'lxml').find_all('tbody')[3].find_all('tr')[n].find_all('td')[1].text.strip()
        dick[c] = v
    df = pd.DataFrame(dick.values(), columns = [i], index = dick.keys())
    secRes90 = pd.concat([secRes90,df], sort = True, axis =1)
# Out:
# 201804
# 201805
# 201806
# 201807
# 201808

# %%
secRes90 = secRes90[sorted(secRes90.columns)]

# %%
secRes90 = secRes90[1:]
# Out:
#              201407 201408 201409 201410 201411 201412 201501 201502 201503  \
# Anqing         99.7   99.5   99.0   99.2   99.1   99.6   99.9   99.7   99.9
# Baotou         99.5   98.7   99.2   99.1   99.1   99.7   99.9   99.5   99.2
# Beihai         99.7   99.1   98.8   98.9   98.9   99.5   99.1   99.5   99.6
# Beijing        98.8   99.2   99.1   98.7  100.2  100.9  100.3   99.9   99.9
# Bengbu         99.7   99.2   98.4   98.9   98.5   99.0   99.1   99.5   99.4
# Changchun      99.8   99.6   99.1   99.0   99.0   99.4   99.5   99.7   99.6
# Changde       100.0   99.6   99.4   99.2   99.2   99.9  100.0   99.3   99.7
# Changsha      100.1   98.5   99.5   99.1   99.3   99.6   99.8  100.0   99.8
# Chengdu        99.7   99.0   99.1   99.0   99.3   99.8   99.8   99.3   99.7
# Chongqing      99.6   99.3   99.2   98.8   99.2   99.6   99.8   99.7   99.6
# Dali           99.6   99.2   99.6   99.4   99.3   99.6   98.7   99.6   99.8
# Dalian         99.5   98.9   99.1   99.2   99.0   99.5   99.9   99.9   99.9
# Dandong        99.6   99.3   98.8   98.7   98.8   99.2   98.8   99.1   99.4
# Fuzhou         99.3   99.2   99.4   99.1   99.2   99.7   99.8   99.7   99.5
# Ganzhou        99.8   98.8   98.3   98.6   99.1  100.0  100.3   99.5  100.5
# Guangzhou      99.8   99.1   98.9   99.0  100.0   99.9   99.5   99.8  100.0
# Guilin        100.2   99.2   99.8   98.7   98.5   99.9   99.3   99.3   99.0
# Guiyang       100.1   99.5   99.7   99.2   99.1   99.4   99.9   99.7   99.8
# Haikou         99.6   99.1   99.4   99.0   99.2   99.5   99.3   99.3   99.3
# Hangzhou       99.1   98.9   99.6   99.4  100.3   99.9   99.8   99.7   99.9
# Harbin        100.0  100.0   99.4   99.2   99.2   98.0   99.7   99.9   99.4
# Hefei          99.9   99.3  100.3   99.2   98.9   99.8  100.1   99.5   99.5
# Hohhot         99.6   99.3   99.5   99.5   98.9   99.6   99.8   99.7   99.8
# Huizhou        99.4   98.6   98.9   99.1   99.2   99.7   99.4   99.5   99.3
# Jilin          99.3   99.3   99.4   99.5   98.8   99.3   99.8   99.5   99.5
# Jinan          99.6   99.1   99.3   99.2   99.4   99.2   99.1   99.8   99.9
# Jinhua         99.5   99.1   99.4   98.7   98.9   99.6   99.7   99.9   99.6
# Jining         99.6   99.0   99.0   99.2   99.0   99.7   99.9   99.8   99.3
# Jinzhou        99.6   99.0   99.1   99.3   98.6   99.3   98.7   99.0   98.8
# Jiujiang       99.5   99.3   99.2   99.4   99.0   99.7  100.1   99.5  100.0
# ...             ...    ...    ...    ...    ...    ...    ...    ...    ...
# Jinzhou       100.7  100.3  100.5
# Jiujiang      100.2  100.5  101.1
# ...             ...    ...    ...
# Pingdingshan  100.5  100.7  101.2
# Qingdao       100.9  100.6  102.4
# Qinhuangdao   100.6  100.5  101.0
# Quanzhou      100.2  100.3  100.8
# Sanya         101.7  101.9  103.6
# Shanghai       99.7   99.7   99.5
# Shaoguan      100.6  100.5  100.7
# Shenyang      100.6  101.4  101.2
# Shenzhen      100.8  100.4  100.4
# Shijiazhuang  100.9  100.7  101.5
# Taiyuan       100.9  100.6  101.1
# Tangshan      100.2  101.2  101.4
# Tianjin       101.8  102.6   99.7
# Urumqi        101.9  100.4  100.3
# Wenzhou       101.6  100.4  100.3
# Wuhan         102.3  100.5  101.2
# Wuxi          100.5  100.6  101.1
# Xiamen         99.7   99.9   99.5
# Xiangfan      100.6  100.4  101.3
# Xining        100.1  100.9  100.2
# Xi’an         101.8  101.2  101.0
# Xuzhou        100.7  100.5  101.0
# Yangzhou      100.3  100.3  101.9
# Yantai        100.8  100.9  102.3
# Yichang       100.6  100.5  101.9
# Yinchuan      100.0  100.8  100.9
# Yueyang       100.5  100.6  100.8
# Zhanjiang     100.2  100.5  100.9
# Zhengzhou     100.0  100.7  101.0
# Zunyi         100.3  101.3  101.8
#
# [70 rows x 38 columns]

# %%
secRes90.to_csv('secRes90.csv')

# %%
fig = plt.figure(figsize=(10,5))
shenzhen = secRes.loc['Shenzhen',:].astype(float)
beijing = secRes.loc['Beijing',:].astype(float)
plt.plot(secRes90.columns, shenzhen)
plt.plot(secRes90.columns, beijing)
plt.xticks(rotation=45)
plt.title('Second-hand residential properties')
plt.show()

# %% [markdown]
# #### 4 table layout

# %%
for i in layout[4][:1]:
    for n in range(4):
        for m in range(6):
            print(beauty(tables[i], 'lxml').find_all('tbody')[n].find_all('tr')[m].text)
# Out:
#   Sales Price Indices of Residential Buildings in 70 Large and Medium-Sized Cities
#   Table I
#   Cities   Price Indices of Newly Constructed Residential Buildings   Cities   Price Indices of Newly Constructed Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
#   Beijing    101.3    98.9    121.3    Tangshan    100.0    95.0    98.1
#   Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Table II
#   Cities   Price Indices of Newly Constructed Commercial Residential Buildings   Cities   Price Indices of Newly Constructed Commercial Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
#   Beijing*    101.6    98.6    127.4    Tangshan    100.0    94.6    97.9
#     Sales Price Indices of Residential Buildings  in 70 Large and Medium-Sized Cities
#   Table III
#   Cities   Price Indices of Second-Hand Residential Buildings   Cities   Price Indices of Second-Hand Residential Buildings
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
#   Beijing    102.3    107.2    126.1    Tangshan    100.0    96.3    100.1
#     Price Indices of Newly Constructed Residential Buildings  by Floor Space in 70 Large and Medium-Sized Cities
#   Table IV
#   Cities   90m2 and Below   90-144m2   Above 144m2
#   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base   M/M   Y/Y   Fixed Base
#
#   Beijing    100.9    92.5    121.0    101.9    97.7    126.0    101.8    104.0    133.6

# %%
newRes = pd.read_csv('newRes38.csv')
newRes.set_index(keys = newRes.columns[0], drop = True, inplace= True)
newRes.index.name = ''
